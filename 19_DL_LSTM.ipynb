# %% [markdown]
# # Deep learning - LSTM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, RNN

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
train_df = pd.read_csv('data/train.csv')
val_df = pd.read_csv('data/val.csv')
test_df = pd.read_csv('data/test.csv')

# %%
def format_timeseries_data(df, input_length, output_length, target_names):
    
    if target_names is not None:
        target_indices = {name: i for i, name in enumerate(target_names)}
    col_indices = {name: i for i, name in enumerate(df.columns)}
    
    total_length = input_length + output_length
    
    input_slice = slice(0, input_length)
    output_slice = slice(input_length, None)
    
    data = np.array(df, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=total_length,
        sequence_stride=1,
        shuffle=False,
        batch_size=32
    )
    
    def split_to_input_output(x):
            
        inputs = x[:, input_slice, :]
        outputs = x[:, output_slice, :]
        
        if target_names is not None:
            outputs = tf.stack(
                [outputs[:,:,col_indices[name]] for name in target_names],
                axis=-1
            )

        inputs.set_shape([None, input_length, None])
        outputs.set_shape([None, output_length, None])
    
        return inputs, outputs
    
    ds = ds.map(split_to_input_output)
    
    return ds

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 2:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
lr_scheduler = LearningRateScheduler(scheduler)

def train_model(model, train_ds, val_ds, patience=5, max_epochs=50, use_scheduler=False):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    if use_scheduler == True:
        history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping, lr_scheduler])
    
    return history

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss')
    ax1.legend(loc='best')

    ax2.plot(history.history['mean_absolute_error'], label='Train')
    ax2.plot(history.history['val_mean_absolute_error'], label='Validation')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('MAE')
    ax2.set_title('Mean absolute error')
    ax2.legend(loc='best')

    plt.tight_layout()

# %%
def plot_predictions(model, sample_batch, model_type):
    
    inputs, outputs = sample_batch
    preds = model(inputs)
    
    if model_type == 'single_step':      

        fig, ax = plt.subplots()

        actual_scaled = outputs.numpy().flatten()
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train
        
        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_step':

        fig, ax = plt.subplots()
        
        actual_scaled = outputs.numpy().flatten()[:48]
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()[:48]
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_output':
        
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
        
        OT_actual_scaled = outputs.numpy().flatten()[0::2]
        OT_actual = OT_actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        OT_predictions_scaled = preds.numpy().flatten()[0::2]
        OT_predictions = OT_predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        MULL_actual_scaled = outputs.numpy().flatten()[1::2]
        MULL_actual = MULL_actual_scaled * (MULL_max_test - MULL_min_test) + MULL_min_test
        
        MULL_predictions_scaled = preds.numpy().flatten()[1::2]
        MULL_predictions = MULL_predictions_scaled * (MULL_max_train - MULL_min_train) + MULL_min_train
        
        ax1.plot(OT_actual, label='Actual')
        ax1.plot(OT_predictions, label='Predicted')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Oil temperature')
        ax1.legend(loc='best')
        ax1.set_title('Predictions on a sample batch')
        
        ax2.plot(MULL_actual, label='Actual')
        ax2.plot(MULL_predictions, label='Predicted')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('MULL')
        ax2.legend(loc='best')
        
    plt.tight_layout()

# %%
def plot_evaluation(model_list, mae):
    
    fig, ax = plt.subplots()
    
    ax.bar(model_list, mae, width=0.3)
    ax.set_ylabel('MAE')
    ax.set_xlabel('Models')
    ax.set_ylim(0, max(mae)+0.15)
    for index, value in enumerate(mae):
        ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
    
    plt.tight_layout()

# %%
MULL_max_train = 7.568999767303468
MULL_min_train = -5.934000015258789
MULL_max_test = 4.690999984741211
MULL_min_test = -3.3399999141693115

OT_max_train = 46.00699996948242
OT_min_train = -4.079999923706056
OT_max_test = 17.165000915527347
OT_min_test = 3.025000095367432

# %% [markdown]
# ## Single-step model

# %%
train_ds_ss = format_timeseries_data(train_df, 1, 1, ['OT'])
val_ds_ss = format_timeseries_data(val_df, 1, 1, ['OT'])
test_ds_ss = format_timeseries_data(test_df, 1, 1, ['OT'])

ss_sample_batch = next(iter(test_ds_ss))

# %%
ss_lstm = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1)
])

ss_lstm_history = train_model(ss_lstm, train_ds_ss, val_ds_ss, use_scheduler=True)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 5s 4ms/step - loss: 0.0266 - mean_absolute_error: 0.0918 - val_loss: 0.0054 - val_mean_absolute_error: 0.0603
# Epoch 2/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0602 - val_loss: 0.0039 - val_mean_absolute_error: 0.0479
# Epoch 3/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0043 - mean_absolute_error: 0.0507 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 4/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0037 - mean_absolute_error: 0.0468 - val_loss: 0.0069 - val_mean_absolute_error: 0.0681
# Epoch 5/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0039 - mean_absolute_error: 0.0463 - val_loss: 0.0054 - val_mean_absolute_error: 0.0586
# Epoch 6/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0456 - val_loss: 0.0025 - val_mean_absolute_error: 0.0398
# Epoch 7/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0423 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 8/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0379 - val_loss: 0.0042 - val_mean_absolute_error: 0.0537
# Epoch 9/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0344 - val_loss: 0.0072 - val_mean_absolute_error: 0.0711
# Epoch 10/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0072 - val_mean_absolute_error: 0.0710
# Epoch 11/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0299 - val_loss: 0.0055 - val_mean_absolute_error: 0.0617
# Epoch 12/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0264 - val_loss: 0.0056 - val_mean_absolute_error: 0.0636
# Epoch 1/50
# 382/382 [==============================] - 1s 3ms/step - loss: 9.6198e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0086 - val_mean_absolute_error: 0.0808 - lr: 0.0010
# Epoch 2/50
# 382/382 [==============================] - 1s 3ms/step - loss: 7.2945e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0100 - val_mean_absolute_error: 0.0874 - lr: 0.0010
# Epoch 3/50
# 382/382 [==============================] - 1s 3ms/step - loss: 6.3646e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0063 - val_mean_absolute_error: 0.0678 - lr: 9.0484e-04
# Epoch 4/50
# 382/382 [==============================] - 1s 3ms/step - loss: 5.7264e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0027 - val_mean_absolute_error: 0.0440 - lr: 8.1873e-04
# Epoch 5/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.9299e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0019 - val_mean_absolute_error: 0.0372 - lr: 7.4082e-04
# Epoch 6/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.6799e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0024 - val_mean_absolute_error: 0.0421 - lr: 6.7032e-04
# Epoch 7/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.5663e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0026 - val_mean_absolute_error: 0.0425 - lr: 6.0653e-04
# Epoch 8/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.4525e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0019 - val_mean_absolute_error: 0.0354 - lr: 5.4881e-04
# Epoch 9/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.3724e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0013 - val_mean_absolute_error: 0.0293 - lr: 4.9659e-04
# Epoch 10/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.3315e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291 - lr: 4.4933e-04
# Epoch 11/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.3253e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313 - lr: 4.0657e-04
# Epoch 12/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2840e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311 - lr: 3.6788e-04
# Epoch 13/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2456e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283 - lr: 3.3287e-04
# Epoch 14/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2352e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - lr: 3.0119e-04
# Epoch 15/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2507e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252 - lr: 2.7253e-04
# Epoch 16/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2721e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248 - lr: 2.4660e-04
# Epoch 17/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.2887e-04 - mean_absolute_error: 0.0146 - val_loss: 9.2917e-04 - val_mean_absolute_error: 0.0234 - lr: 2.2313e-04
# Epoch 18/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.3171e-04 - mean_absolute_error: 0.0147 - val_loss: 7.7098e-04 - val_mean_absolute_error: 0.0215 - lr: 2.0190e-04
# Epoch 19/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.3616e-04 - mean_absolute_error: 0.0148 - val_loss: 6.5520e-04 - val_mean_absolute_error: 0.0202 - lr: 1.8268e-04
# Epoch 20/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.4096e-04 - mean_absolute_error: 0.0149 - val_loss: 5.9289e-04 - val_mean_absolute_error: 0.0195 - lr: 1.6530e-04
# Epoch 21/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.4493e-04 - mean_absolute_error: 0.0149 - val_loss: 5.5476e-04 - val_mean_absolute_error: 0.0192 - lr: 1.4957e-04
# Epoch 22/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.4848e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2885e-04 - val_mean_absolute_error: 0.0191 - lr: 1.3534e-04
# Epoch 23/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.5248e-04 - mean_absolute_error: 0.0151 - val_loss: 5.1986e-04 - val_mean_absolute_error: 0.0191 - lr: 1.2246e-04
# Epoch 24/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.5732e-04 - mean_absolute_error: 0.0152 - val_loss: 5.2912e-04 - val_mean_absolute_error: 0.0194 - lr: 1.1080e-04
# Epoch 25/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.6347e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5660e-04 - val_mean_absolute_error: 0.0198 - lr: 1.0026e-04
# Epoch 26/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.7174e-04 - mean_absolute_error: 0.0156 - val_loss: 6.0425e-04 - val_mean_absolute_error: 0.0206 - lr: 9.0718e-05
# Epoch 27/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.8300e-04 - mean_absolute_error: 0.0158 - val_loss: 6.6749e-04 - val_mean_absolute_error: 0.0215 - lr: 8.2085e-05
# Epoch 28/50
# 382/382 [==============================] - 1s 3ms/step - loss: 4.9781e-04 - mean_absolute_error: 0.0162 - val_loss: 7.2503e-04 - val_mean_absolute_error: 0.0223 - lr: 7.4274e-05

# %%
plot_history(ss_lstm_history)

# %%
plot_predictions(ss_lstm, ss_sample_batch, 'single_step')

# %% [markdown]
# ### Evaluation

# %%
model_list = ['Linear', 'DNN', 'LSTM']

ss_mae = [0.032, 0.046]
ss_mae.append(ss_lstm.evaluate(test_ds_ss)[1])

plot_evaluation(model_list, ss_mae)
# Out:
# 55/55 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0357

# %% [markdown]
# ## Multi-step model

# %%
train_ds_ms = format_timeseries_data(train_df, 24, 24, ['OT'])
val_ds_ms = format_timeseries_data(val_df, 24, 24, ['OT'])
test_ds_ms = format_timeseries_data(test_df, 24, 24, ['OT'])

ms_sample_batch = next(iter(test_ds_ms))

# %%
ms_lstm = Sequential([
    LSTM(32, return_sequences=True),
    LSTM(16, return_sequences=True),
    Dense(1)
])

ms_lstm_history = train_model(ms_lstm, train_ds_ms, val_ds_ms)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 12s 21ms/step - loss: 0.0242 - mean_absolute_error: 0.0973 - val_loss: 0.0317 - val_mean_absolute_error: 0.1579
# Epoch 2/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0112 - mean_absolute_error: 0.0745 - val_loss: 0.0296 - val_mean_absolute_error: 0.1542
# Epoch 3/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0087 - mean_absolute_error: 0.0684 - val_loss: 0.0170 - val_mean_absolute_error: 0.1099
# Epoch 4/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0651 - val_loss: 0.0043 - val_mean_absolute_error: 0.0491
# Epoch 5/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0069 - mean_absolute_error: 0.0637 - val_loss: 0.0062 - val_mean_absolute_error: 0.0638
# Epoch 6/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0643 - val_loss: 0.0080 - val_mean_absolute_error: 0.0713
# Epoch 7/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0077 - mean_absolute_error: 0.0657 - val_loss: 0.0067 - val_mean_absolute_error: 0.0652
# Epoch 8/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0082 - mean_absolute_error: 0.0668 - val_loss: 0.0070 - val_mean_absolute_error: 0.0670
# Epoch 9/50
# 380/380 [==============================] - 7s 18ms/step - loss: 0.0078 - mean_absolute_error: 0.0651 - val_loss: 0.0181 - val_mean_absolute_error: 0.1036

# %%
plot_history(ms_lstm_history)

# %%
plot_predictions(ms_lstm, ms_sample_batch, 'multi_step')

# %%
ms_mae = [0.123, 0.154]
ms_mae.append(ms_lstm.evaluate(test_ds_ms)[1])

plot_evaluation(model_list, ms_mae)
# Out:
# 53/53 [==============================] - 0s 6ms/step - loss: 0.0726 - mean_absolute_error: 0.2202

# %% [markdown]
# ## Multi-output model

# %%
train_ds_mo = format_timeseries_data(train_df, 1, 1, ['OT', 'MULL'])
val_ds_mo = format_timeseries_data(val_df, 1, 1, ['OT', 'MULL'])
test_ds_mo = format_timeseries_data(test_df, 1, 1, ['OT', 'MULL'])

mo_sample_batch = next(iter(test_ds_mo))

# %%
mo_lstm = Sequential([
    LSTM(32, return_sequences=True),
    Dense(2)
])

mo_lstm_history = train_model(mo_lstm, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 4s 4ms/step - loss: 0.0306 - mean_absolute_error: 0.1084 - val_loss: 0.0248 - val_mean_absolute_error: 0.1372
# Epoch 2/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0618 - val_loss: 0.0125 - val_mean_absolute_error: 0.0891
# Epoch 3/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0531 - val_loss: 0.0029 - val_mean_absolute_error: 0.0421
# Epoch 4/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0039 - mean_absolute_error: 0.0484 - val_loss: 0.0079 - val_mean_absolute_error: 0.0692
# Epoch 5/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0486 - val_loss: 0.0044 - val_mean_absolute_error: 0.0514
# Epoch 6/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0041 - mean_absolute_error: 0.0476 - val_loss: 0.0030 - val_mean_absolute_error: 0.0425
# Epoch 7/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0439 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 8/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0402 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 9/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0378 - val_loss: 0.0046 - val_mean_absolute_error: 0.0536
# Epoch 10/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0364 - val_loss: 0.0041 - val_mean_absolute_error: 0.0504
# Epoch 11/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0349 - val_loss: 0.0031 - val_mean_absolute_error: 0.0439
# Epoch 12/50
# 382/382 [==============================] - 1s 3ms/step - loss: 0.0020 - mean_absolute_error: 0.0325 - val_loss: 0.0033 - val_mean_absolute_error: 0.0454

# %%
plot_history(mo_lstm_history)

# %%
plot_predictions(mo_lstm, mo_sample_batch, 'multi_output')

# %%
mo_mae = [0.05, 0.069]
mo_mae.append(mo_lstm.evaluate(test_ds_mo)[1])

plot_evaluation(model_list, mo_mae)
# Out:
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0843
