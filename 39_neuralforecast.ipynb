# %%
# !pip install neuralforecast utilsforecast
# Out:
# Collecting neuralforecast
#   Downloading neuralforecast-3.0.2-py3-none-any.whl.metadata (14 kB)
# Collecting utilsforecast
#   Downloading utilsforecast-0.2.12-py3-none-any.whl.metadata (7.6 kB)
# Collecting coreforecast>=0.0.6 (from neuralforecast)
#   Downloading coreforecast-0.0.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from neuralforecast) (2025.7.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from neuralforecast) (2.0.2)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.11/dist-packages (from neuralforecast) (2.2.2)
# Requirement already satisfied: torch<=2.6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from neuralforecast) (2.6.0+cu124)
# Collecting pytorch-lightning>=2.0.0 (from neuralforecast)
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Collecting ray>=2.2.0 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading ray-2.48.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting optuna (from neuralforecast)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from utilsforecast) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.5->neuralforecast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.5->neuralforecast) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.5->neuralforecast) (2025.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (6.0.2)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading torchmetrics-1.7.4-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.14.1)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning>=2.0.0->neuralforecast)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (4.25.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (1.1.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (5.29.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.32.3)
# Collecting tensorboardX>=1.9 (from ray[tune]>=2.2.0->neuralforecast)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (18.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<=2.6.0,>=2.0.0->neuralforecast)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.6.0,>=2.0.0->neuralforecast) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<=2.6.0,>=2.0.0->neuralforecast) (1.3.0)
# Collecting alembic>=1.5.0 (from optuna->neuralforecast)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna->neuralforecast)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->neuralforecast) (2.0.41)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->neuralforecast) (1.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning>=2.0.0->neuralforecast) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->neuralforecast) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->neuralforecast) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.6.0,>=2.0.0->neuralforecast) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2025.7.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.20.1)
# Downloading neuralforecast-3.0.2-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 13.3 MB/s eta 0:00:00
# Downloading utilsforecast-0.2.12-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
# Downloading coreforecast-0.0.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 24.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 49.1 MB/s eta 0:00:00
# Downloading ray-2.48.0-cp311-cp311-manylinux2014_x86_64.whl (70.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.0 MB/s eta 0:00:00
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 32.5 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 23.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 51.0 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: tensorboardX, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, coreforecast, colorlog, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, utilsforecast, optuna, nvidia-cusolver-cu12, ray, torchmetrics, pytorch-lightning, neuralforecast
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed alembic-1.16.4 colorlog-6.9.0 coreforecast-0.0.16 lightning-utilities-0.14.3 neuralforecast-3.0.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.4.0 pytorch-lightning-2.5.2 ray-2.48.0 tensorboardX-2.6.4 torchmetrics-1.7.4 utilsforecast-0.2.12

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utilsforecast.plotting import plot_series
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import *

from neuralforecast.core import NeuralForecast
from neuralforecast.models import MLP, MLPMultivariate
from neuralforecast.losses.pytorch import *

import warnings
warnings.filterwarnings("ignore")

# %%
def plot_metrics_bar(eval_df):
    methods = eval_df.columns[1:]
    values = eval_df.iloc[0].values[1:]

    sorted_data = sorted(zip(methods, values), key=lambda x: x[1], reverse=True)
    methods_sorted, values_sorted = zip(*sorted_data)

    plt.figure(figsize=(10, 6))
    bars = plt.bar(methods_sorted, values_sorted)

    for bar, value in zip(bars, values_sorted):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05,
                 f'{value:.3f}', ha='center', va='bottom', fontweight='bold')

    plt.xlabel('Methods')
    plt.ylabel('Mean absolute error (MAE)')
    plt.tight_layout()

    plt.show()

# %%
DATA_URL = "https://raw.githubusercontent.com/marcopeix/youtube_tutorials/refs/heads/main/data/daily_sales_french_bakery.csv"
df = pd.read_csv(DATA_URL, parse_dates=["ds"])
df = df.groupby('unique_id').filter(lambda x: len(x) >= 28)
df.head()
# Out:
#     unique_id         ds     y  unit_price
# 0  12 MACARON 2022-07-13  10.0        10.0
# 1  12 MACARON 2022-07-14   0.0        10.0
# 2  12 MACARON 2022-07-15   0.0        10.0
# 3  12 MACARON 2022-07-16  10.0        10.0
# 4  12 MACARON 2022-07-17  30.0        10.0

# %%
plot_series(df=df, ids=["BAGUETTE", "CROISSANT"], palette="viridis")

# %%
plot_series(df=df, ids=["BAGUETTE", "CROISSANT"], max_insample_length=56, palette="viridis")

# %%
unique_ids = ["BAGUETTE", "CROISSANT"]
df = df[df["unique_id"].isin(unique_ids)]

# %% [markdown]
# ## Forecasting and cross-validation

# %%
HORIZON = 7

# %%
models = [
    MLP(
        h=HORIZON,
        input_size=14,
        futr_exog_list=["unit_price"],
        num_layers=2,
        hidden_size=1024,
        loss=MAE(),
        valid_loss=MSE(),
        max_steps=1000,
        early_stop_patience_steps=3,
        val_check_steps=100,
        scaler_type="identity"
        ),
    MLPMultivariate(
        h=HORIZON,
        input_size=14,
        n_series=2,
        futr_exog_list=["unit_price"],
        num_layers=2,
        hidden_size=1024,
        loss=MAE(),
        valid_loss=MSE(),
        max_steps=1000,
        early_stop_patience_steps=3,
        val_check_steps=100,
        scaler_type="identity"
    )
]
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:lightning_fabric.utilities.seed:Seed set to 1

# %%
nf = NeuralForecast(models=models, freq="D")
nf.fit(df=df, val_size=HORIZON)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | valid_loss   | MSE           | 0      | train
# 2 | padder_train | ConstantPad1d | 0      | train
# 3 | scaler       | TemporalNorm  | 0      | train
# 4 | mlp          | ModuleList    | 1.1 M  | train
# 5 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | valid_loss   | MSE           | 0      | train
# 2 | padder_train | ConstantPad1d | 0      | train
# 3 | scaler       | TemporalNorm  | 0      | train
# 4 | mlp          | ModuleList    | 1.1 M  | train
# 5 | out          | Linear        | 14.3 K | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.547     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]

# %%
last_date = df['ds'].max()
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=HORIZON, freq='D')

# Get the last unit_price for each unique_id
last_unit_prices = df.groupby('unique_id')['unit_price'].last()

futr_df = []
for uid in unique_ids:
    last_price = last_unit_prices[uid]
    for date in future_dates:
        futr_df.append({
            'unique_id': uid,
            'ds': date,
            'unit_price': last_price
        })

futr_df = pd.DataFrame(futr_df)
futr_df
# Out:
#     unique_id         ds  unit_price
# 0    BAGUETTE 2022-10-01         1.0
# 1    BAGUETTE 2022-10-02         1.0
# 2    BAGUETTE 2022-10-03         1.0
# 3    BAGUETTE 2022-10-04         1.0
# 4    BAGUETTE 2022-10-05         1.0
# 5    BAGUETTE 2022-10-06         1.0
# 6    BAGUETTE 2022-10-07         1.0
# 7   CROISSANT 2022-10-01         1.2
# 8   CROISSANT 2022-10-02         1.2
# 9   CROISSANT 2022-10-03         1.2
# 10  CROISSANT 2022-10-04         1.2
# 11  CROISSANT 2022-10-05         1.2
# 12  CROISSANT 2022-10-06         1.2
# 13  CROISSANT 2022-10-07         1.2

# %%
preds = nf.predict(futr_df=futr_df)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
plot_series(df=df, forecasts_df=preds, max_insample_length=56, palette="viridis")

# %% [markdown]
# ### Cross-validation

# %%
cv_df = nf.cross_validation(
    df=df,
    step_size=HORIZON,
    val_size=HORIZON,
    test_size=8*HORIZON,
    refit=False,
    n_windows=None,
)

evaluation = evaluate(
    cv_df.drop(["cutoff"], axis=1),
    metrics=[mae, rmse],
)

evaluation = evaluation.drop(['unique_id'], axis=1).groupby('metric').mean().reset_index()
evaluation
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | valid_loss   | MSE           | 0      | train
# 2 | padder_train | ConstantPad1d | 0      | train
# 3 | scaler       | TemporalNorm  | 0      | train
# 4 | mlp          | ModuleList    | 1.1 M  | train
# 5 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | valid_loss   | MSE           | 0      | train
# 2 | padder_train | ConstantPad1d | 0      | train
# 3 | scaler       | TemporalNorm  | 0      | train
# 4 | mlp          | ModuleList    | 1.1 M  | train
# 5 | out          | Linear        | 14.3 K | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.547     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
#   metric        MLP  MLPMultivariate
# 0    mae   9.041299        11.839362
# 1   rmse  13.339327        17.856718

# %%
plot_metrics_bar(evaluation)

# %%
plot_series(
    df=df,
    forecasts_df=cv_df.drop(["y", "cutoff"], axis=1),
    max_insample_length=140,
    palette="viridis"
)

# %% [markdown]
# ## Probabilistic forecasting
# ### Loss function

# %%
models = [
    MLP(
        h=HORIZON,
        input_size=14,
        futr_exog_list=["unit_price"],
        num_layers=2,
        hidden_size=1024,
        loss=HuberMQLoss(level=[80]),
        valid_loss=HuberMQLoss(level=[80]),
        max_steps=1000,
        early_stop_patience_steps=3,
        val_check_steps=100,
        scaler_type="identity"
        )
]

nf = NeuralForecast(models=models, freq="D")

cv_df_mqloss = nf.cross_validation(
    df=df,
    step_size=HORIZON,
    val_size=HORIZON,
    test_size=8*HORIZON,
    refit=False,
    n_windows=None,
    level=[80]
)

cv_df_mqloss = cv_df_mqloss.rename(columns={"MLP-median": "MLP"})

cv_df_mqloss.head()
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | HuberMQLoss   | 3      | train
# 1 | valid_loss   | HuberMQLoss   | 3      | train
# 2 | padder_train | ConstantPad1d | 0      | train
# 3 | scaler       | TemporalNorm  | 0      | train
# 4 | mlp          | ModuleList    | 1.1 M  | train
# 5 | out          | Linear        | 21.5 K | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 6         Non-trainable params
# 1.1 M     Total params
# 4.432     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
#   unique_id         ds     cutoff        MLP  MLP-lo-80  MLP-hi-80     y
# 0  BAGUETTE 2022-08-06 2022-08-05  65.985405  44.506142  74.380966  55.0
# 1  BAGUETTE 2022-08-07 2022-08-05  56.214439  46.652748  75.169479  67.0
# 2  BAGUETTE 2022-08-08 2022-08-05  50.392860  39.481998  67.926498  61.0
# 3  BAGUETTE 2022-08-09 2022-08-05  43.181435  31.199577  59.629227  52.0
# 4  BAGUETTE 2022-08-10 2022-08-05  48.124493  35.545261  61.120754  57.0

# %%
metrics = [
    scaled_crps
]

evaluation = evaluate(
    cv_df_mqloss.drop(["ds", "cutoff"], axis=1),
    metrics=metrics,
    models=["MLP"],
    level=[80]
)
evaluation = evaluation.drop(['unique_id'], axis=1).groupby('metric').mean().reset_index()
evaluation
# Out:
#         metric      MLP
# 0  scaled_crps  0.19874

# %%
plot_series(
    df=df,
    forecasts_df=cv_df_mqloss.drop(["y", "cutoff"], axis=1),
    # models=["MLP"],
    max_insample_length=140,
    level=[80],
    palette="viridis"
)

# %% [markdown]
# ### Conformal predictions

# %%
from neuralforecast.utils import PredictionIntervals

# %%
prediction_intervals = PredictionIntervals()

models = [
    MLP(
        h=HORIZON,
        input_size=14,
        futr_exog_list=["unit_price"],
        num_layers=2,
        hidden_size=1024,
        loss=MAE(),
        max_steps=400,
        scaler_type="identity"
        )
]

nf = NeuralForecast(models=models, freq="D")

cv_df_conformal = nf.cross_validation(
    df=df,
    step_size=HORIZON,
    test_size=8*HORIZON,
    refit=True,
    n_windows=None,
    prediction_intervals=prediction_intervals,
    level=[80]
)

cv_df_conformal.head()
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
#   unique_id         ds     cutoff        MLP  MLP-lo-80  MLP-hi-80     y
# 0  BAGUETTE 2022-08-06 2022-08-05  58.077259  38.066451  78.088067  55.0
# 1  BAGUETTE 2022-08-07 2022-08-05  46.815273  24.400570  69.229977  67.0
# 2  BAGUETTE 2022-08-08 2022-08-05  42.592472  30.648862  54.536082  61.0
# 3  BAGUETTE 2022-08-09 2022-08-05  39.358856  25.850595  52.867118  52.0
# 4  BAGUETTE 2022-08-10 2022-08-05  45.092567  41.361897  48.823238  57.0

# %%
metrics = [
    scaled_crps
]

evaluation = evaluate(
    cv_df_conformal.drop(["ds", "cutoff"], axis=1),
    metrics=metrics,
    models=["MLP"],
    level=[80]
)
evaluation = evaluation.drop(['unique_id'], axis=1).groupby('metric').mean().reset_index()
evaluation
# Out:
#         metric       MLP
# 0  scaled_crps  0.191457

# %%
plot_series(
    df=df,
    forecasts_df=cv_df_conformal.drop(["y", "cutoff"], axis=1),
    # models=["MLP"],
    max_insample_length=140,
    level=[80],
    palette="viridis"
)

# %% [markdown]
# ## Training on large datasets

# %%
import os

# %%
output_dir = "partitioned_data"
os.makedirs(output_dir, exist_ok=True)

# Save partitioned by unique_id
df.to_parquet(output_dir, partition_cols=['unique_id'], index=False)

# Get list of partition directories
files_list = [f"{output_dir}/{dir_name}" for dir_name in os.listdir(output_dir)]

# %%
files_list
# Out:
# ['partitioned_data/unique_id=BAGUETTE', 'partitioned_data/unique_id=CROISSANT']

# %%
models = [
    MLP(
        h=HORIZON,
        input_size=14,
        futr_exog_list=["unit_price"],
        num_layers=2,
        hidden_size=1024,
        loss=MAE(),
        max_steps=400,
        scaler_type="identity"
        )
]

nf = NeuralForecast(models=models, freq="D")
nf.fit(df=files_list)
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 1.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 1.1 M     Trainable params
# 0         Non-trainable params
# 1.1 M     Total params
# 4.375     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=400` reached.

# %%
input_df = df.groupby('unique_id').tail(14)

preds = nf.predict(df=input_df, futr_df=futr_df)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
plot_series(df=df, forecasts_df=preds, max_insample_length=56, palette="viridis")

# %% [markdown]
# ## Hyperparameter optimization

# %%
from ray import tune
from ray.tune.search.hyperopt import HyperOptSearch

from neuralforecast.auto import AutoMLP

# %%
mlp_config = {
    "max_steps": 100,
    "input_size": tune.choice([7, 14]),
    "hidden_size": tune.choice([512, 1024]),
    "num_layers": tune.choice([2, 3]),
    "learning_rate": tune.loguniform(1e-5, 1e-1),
}

# %%
model = AutoMLP(
    h=HORIZON,
    loss=MAE(),
    config=mlp_config,
    search_alg=HyperOptSearch(),
    backend='ray',
    num_samples=10
)

# %%
nf = NeuralForecast(models=[model], freq='D')
nf.fit(df=df.drop(columns=["unit_price"]), val_size=28)
# Out:
# 2025-07-23 14:52:16,820	INFO worker.py:1927 -- Started a local Ray instance.
# 2025-07-23 14:52:18,397	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +--------------------------------------------------------------------+
# | Configuration for experiment     _train_tune_2025-07-23_14-52-13   |
# +--------------------------------------------------------------------+
# | Search algorithm                 SearchGenerator                   |
# | Scheduler                        FIFOScheduler                     |
# | Number of trials                 10                                |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/_train_tune_2025-07-23_14-52-13
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-07-23_14-52-13_781846_175/artifacts/2025-07-23_14-52-18/_train_tune_2025-07-23_14-52-13/driver_artifacts`
# (_train_tune pid=2483) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=2483) Seed set to 1
# (_train_tune pid=2483) GPU available: True (cuda), used: True
# (_train_tune pid=2483) TPU available: False, using: 0 TPU cores
# (_train_tune pid=2483) HPU available: False, using: 0 HPUs
# (_train_tune pid=2483) 2025-07-23 14:52:29.506447: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=2483) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=2483) E0000 00:00:1753282349.531523    2571 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=2483) E0000 00:00:1753282349.539079    2571 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=2483) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=2483)
# (_train_tune pid=2483)   | Name         | Type          | Params | Mode
# (_train_tune pid=2483) -------------------------------------------------------
# (_train_tune pid=2483) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=2483) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=2483) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=2483) 3 | mlp          | ModuleList    | 1.1 M  | train
# (_train_tune pid=2483) 4 | out          | Linear        | 7.2 K  | train
# (_train_tune pid=2483) -------------------------------------------------------
# (_train_tune pid=2483) 1.1 M     Trainable params
# (_train_tune pid=2483) 0         Non-trainable params
# (_train_tune pid=2483) 1.1 M     Total params
# (_train_tune pid=2483) 4.260     Total estimated model params size (MB)
# (_train_tune pid=2483) 7         Modules in train mode
# (_train_tune pid=2483) 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=21.50, train_loss_epoch=21.50]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=17.60, train_loss_epoch=17.60]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.40, train_loss_epoch=15.40]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.20, train_loss_epoch=14.20]
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.70, train_loss_epoch=13.70]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.70, train_loss_epoch=13.70]
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.10, train_loss_epoch=13.10]
# Epoch 68: 100%|██████████| 1/1 [00:00<00:00, 151.04it/s, v_num=0, train_loss_step=12.80, train_loss_epoch=13.10]
# Epoch 68: 100%|██████████| 1/1 [00:00<00:00, 137.64it/s, v_num=0, train_loss_step=12.80, train_loss_epoch=12.80]
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.80, train_loss_epoch=12.80]
# 2025-07-23 14:52:33,631	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.70, train_loss_epoch=12.70]
# Epoch 81: 100%|██████████| 1/1 [00:00<00:00, 112.23it/s, v_num=0, train_loss_step=12.80, train_loss_epoch=12.80]
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.80, train_loss_epoch=12.80]
# Epoch 94: 100%|██████████| 1/1 [00:00<00:00, 135.07it/s, v_num=0, train_loss_step=12.30, train_loss_epoch=12.30]
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.30, train_loss_epoch=12.30]
# (_train_tune pid=2483) `Trainer.fit` stopped: `max_steps=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 152.02it/s, v_num=0, train_loss_step=12.20, train_loss_epoch=12.40]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 404.86it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 30.37it/s, v_num=0, train_loss_step=12.20, train_loss_epoch=12.20, valid_loss=11.00]
# (_train_tune pid=2599) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=2599) Seed set to 1
# (_train_tune pid=2599) GPU available: True (cuda), used: True
# (_train_tune pid=2599) TPU available: False, using: 0 TPU cores
# (_train_tune pid=2599) HPU available: False, using: 0 HPUs
# (_train_tune pid=2599) 2025-07-23 14:52:44.108505: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=2599) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=2599) E0000 00:00:1753282364.131950    2682 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=2599) E0000 00:00:1753282364.138990    2682 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=2599) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=2599)
# (_train_tune pid=2599)   | Name         | Type          | Params | Mode
# (_train_tune pid=2599) -------------------------------------------------------
# (_train_tune pid=2599) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=2599) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=2599) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=2599) 3 | mlp          | ModuleList    | 2.1 M  | train
# (_train_tune pid=2599) 4 | out          | Linear        | 7.2 K  | train
# (_train_tune pid=2599) -------------------------------------------------------
# (_train_tune pid=2599) 2.1 M     Trainable params
# (_train_tune pid=2599) 0         Non-trainable params
# (_train_tune pid=2599) 2.1 M     Total params
# (_train_tune pid=2599) 8.487     Total estimated model params size (MB)
# (_train_tune pid=2599) 8         Modules in train mode
# (_train_tune pid=2599) 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=41.80, train_loss_epoch=41.80]
# Epoch 12: 100%|██████████| 1/1 [00:00<00:00, 117.30it/s, v_num=0, train_loss_step=32.20, train_loss_epoch=32.20]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=21.50, train_loss_epoch=21.50]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=19.70, train_loss_epoch=19.70]
# Epoch 31: 100%|██████████| 1/1 [00:00<00:00, 106.37it/s, v_num=0, train_loss_step=19.70, train_loss_epoch=19.70]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.50, train_loss_epoch=18.50]
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=17.10, train_loss_epoch=17.10]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.20, train_loss_epoch=16.20]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.40, train_loss_epoch=15.40]
# Epoch 87: 100%|██████████| 1/1 [00:00<00:00, 128.84it/s, v_num=0, train_loss_step=14.80, train_loss_epoch=14.80]
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.80, train_loss_epoch=14.80]
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.80, train_loss_epoch=14.80]
# 2025-07-23 14:52:48,068	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 138.17it/s, v_num=0, train_loss_step=14.00, train_loss_epoch=14.40]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (_train_tune pid=2599)
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 283.53it/s]
# (_train_tune pid=2599)
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 38.49it/s, v_num=0, train_loss_step=14.00, train_loss_epoch=14.00, valid_loss=9.370]
# (_train_tune pid=2599) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=2710) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=2710) Seed set to 1
# (_train_tune pid=2710) GPU available: True (cuda), used: True
# (_train_tune pid=2710) TPU available: False, using: 0 TPU cores
# (_train_tune pid=2710) HPU available: False, using: 0 HPUs
# (_train_tune pid=2710) 2025-07-23 14:53:00.165687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=2710) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=2710) E0000 00:00:1753282380.189363    2800 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=2710) E0000 00:00:1753282380.196611    2800 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=2710) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=2710)
# (_train_tune pid=2710)   | Name         | Type          | Params | Mode
# (_train_tune pid=2710) -------------------------------------------------------
# (_train_tune pid=2710) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=2710) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=2710) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=2710) 3 | mlp          | ModuleList    | 2.1 M  | train
# (_train_tune pid=2710) 4 | out          | Linear        | 7.2 K  | train
# (_train_tune pid=2710) -------------------------------------------------------
# (_train_tune pid=2710) 2.1 M     Trainable params
# (_train_tune pid=2710) 0         Non-trainable params
# (_train_tune pid=2710) 2.1 M     Total params
# (_train_tune pid=2710) 8.487     Total estimated model params size (MB)
# (_train_tune pid=2710) 8         Modules in train mode
# (_train_tune pid=2710) 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 1/1 [00:00<00:00, 138.46it/s, v_num=0, train_loss_step=53.50, train_loss_epoch=53.50]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=24.60, train_loss_epoch=24.60]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 99.53it/s, v_num=0, train_loss_step=20.40, train_loss_epoch=20.30]
# Epoch 22: 100%|██████████| 1/1 [00:00<00:00, 93.86it/s, v_num=0, train_loss_step=20.40, train_loss_epoch=20.40]
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=20.40, train_loss_epoch=20.40]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.60, train_loss_epoch=18.60]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 136.42it/s, v_num=0, train_loss_step=16.70, train_loss_epoch=16.70]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.80, train_loss_epoch=15.80]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.60, train_loss_epoch=14.60]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.10, train_loss_epoch=14.10]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.70, train_loss_epoch=13.70]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.00, train_loss_epoch=13.00]
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.90, train_loss_epoch=12.90]
# (_train_tune pid=2710) `Trainer.fit` stopped: `max_steps=100` reached.
# 2025-07-23 14:53:04,374	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 106.31it/s, v_num=0, train_loss_step=12.50, train_loss_epoch=12.70]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 288.68it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 33.84it/s, v_num=0, train_loss_step=12.50, train_loss_epoch=12.50, valid_loss=9.770]
# (_train_tune pid=2828) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=2828) Seed set to 1
# (_train_tune pid=2828) GPU available: True (cuda), used: True
# (_train_tune pid=2828) TPU available: False, using: 0 TPU cores
# (_train_tune pid=2828) HPU available: False, using: 0 HPUs
# (_train_tune pid=2828) 2025-07-23 14:53:17.292849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=2828) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=2828) E0000 00:00:1753282397.336902    2918 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=2828) E0000 00:00:1753282397.348951    2918 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=2828) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=2828)
# (_train_tune pid=2828)   | Name         | Type          | Params | Mode
# (_train_tune pid=2828) -------------------------------------------------------
# (_train_tune pid=2828) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=2828) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=2828) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=2828) 3 | mlp          | ModuleList    | 532 K  | train
# (_train_tune pid=2828) 4 | out          | Linear        | 3.6 K  | train
# (_train_tune pid=2828) -------------------------------------------------------
# (_train_tune pid=2828) 536 K     Trainable params
# (_train_tune pid=2828) 0         Non-trainable params
# (_train_tune pid=2828) 536 K     Total params
# (_train_tune pid=2828) 2.146     Total estimated model params size (MB)
# (_train_tune pid=2828) 8         Modules in train mode
# (_train_tune pid=2828) 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 138.79it/s, v_num=0, train_loss_step=42.60, train_loss_epoch=43.40]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 127.42it/s, v_num=0, train_loss_step=42.60, train_loss_epoch=42.60]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=42.60, train_loss_epoch=42.60]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=32.50, train_loss_epoch=32.50]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 110.56it/s, v_num=0, train_loss_step=32.50, train_loss_epoch=32.50]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 96.78it/s, v_num=0, train_loss_step=31.50, train_loss_epoch=31.50]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=31.50, train_loss_epoch=31.50]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=20.70, train_loss_epoch=20.70]
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=20.20, train_loss_epoch=20.20]
# Epoch 55: 100%|██████████| 1/1 [00:00<00:00, 153.05it/s, v_num=0, train_loss_step=18.40, train_loss_epoch=18.40]
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.40, train_loss_epoch=18.40]
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.90, train_loss_epoch=16.90]
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.50, train_loss_epoch=15.50]
# 2025-07-23 14:53:23,063	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.20, train_loss_epoch=15.20]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 169.43it/s, v_num=0, train_loss_step=15.10, train_loss_epoch=15.60]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 425.34it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 46.80it/s, v_num=0, train_loss_step=15.10, train_loss_epoch=15.10, valid_loss=10.90]
# (_train_tune pid=2828) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=2959) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=2959) Seed set to 1
# (_train_tune pid=2959) GPU available: True (cuda), used: True
# (_train_tune pid=2959) TPU available: False, using: 0 TPU cores
# (_train_tune pid=2959) HPU available: False, using: 0 HPUs
# (_train_tune pid=2959) 2025-07-23 14:53:34.666715: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=2959) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=2959) E0000 00:00:1753282414.691783    3039 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=2959) E0000 00:00:1753282414.699371    3039 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=2959) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=2959)
# (_train_tune pid=2959)   | Name         | Type          | Params | Mode
# (_train_tune pid=2959) -------------------------------------------------------
# (_train_tune pid=2959) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=2959) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=2959) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=2959) 3 | mlp          | ModuleList    | 529 K  | train
# (_train_tune pid=2959) 4 | out          | Linear        | 3.6 K  | train
# (_train_tune pid=2959) -------------------------------------------------------
# (_train_tune pid=2959) 532 K     Trainable params
# (_train_tune pid=2959) 0         Non-trainable params
# (_train_tune pid=2959) 532 K     Total params
# (_train_tune pid=2959) 2.132     Total estimated model params size (MB)
# (_train_tune pid=2959) 8         Modules in train mode
# (_train_tune pid=2959) 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 156.49it/s, v_num=0, train_loss_step=21.40, train_loss_epoch=24.40]
# Epoch 6: 100%|██████████| 1/1 [00:00<00:00, 141.97it/s, v_num=0, train_loss_step=21.40, train_loss_epoch=21.40]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=21.40, train_loss_epoch=21.40]
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.30, train_loss_epoch=16.30]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 126.32it/s, v_num=0, train_loss_step=16.60, train_loss_epoch=16.30]
# Epoch 20: 100%|██████████| 1/1 [00:00<00:00, 116.30it/s, v_num=0, train_loss_step=16.60, train_loss_epoch=16.60]
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.60, train_loss_epoch=16.60]
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.80, train_loss_epoch=14.80]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 154.48it/s, v_num=0, train_loss_step=14.50, train_loss_epoch=14.80]
# Epoch 34: 100%|██████████| 1/1 [00:00<00:00, 119.83it/s, v_num=0, train_loss_step=14.50, train_loss_epoch=14.50]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.50, train_loss_epoch=14.50]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.10, train_loss_epoch=14.10]
# Epoch 61: 100%|██████████| 1/1 [00:00<00:00, 155.06it/s, v_num=0, train_loss_step=13.80, train_loss_epoch=13.80]
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.80, train_loss_epoch=13.80]
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.30, train_loss_epoch=13.30]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 110.90it/s, v_num=0, train_loss_step=13.20, train_loss_epoch=13.20]
# Epoch 88: 100%|██████████| 1/1 [00:00<00:00, 106.40it/s, v_num=0, train_loss_step=13.20, train_loss_epoch=13.20]
# (_train_tune pid=2959) `Trainer.fit` stopped: `max_steps=100` reached.
# 2025-07-23 14:53:39,064	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 171.95it/s, v_num=0, train_loss_step=12.90, train_loss_epoch=13.00]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 417.55it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 46.59it/s, v_num=0, train_loss_step=12.90, train_loss_epoch=12.90, valid_loss=10.30]
# (_train_tune pid=3072) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=3072) Seed set to 1
# (_train_tune pid=3072) GPU available: True (cuda), used: True
# (_train_tune pid=3072) TPU available: False, using: 0 TPU cores
# (_train_tune pid=3072) HPU available: False, using: 0 HPUs
# (_train_tune pid=3072) 2025-07-23 14:53:50.442273: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=3072) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=3072) E0000 00:00:1753282430.466982    3152 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=3072) E0000 00:00:1753282430.474069    3152 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=3072) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=3072)
# (_train_tune pid=3072)   | Name         | Type          | Params | Mode
# (_train_tune pid=3072) -------------------------------------------------------
# (_train_tune pid=3072) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=3072) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=3072) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=3072) 3 | mlp          | ModuleList    | 2.1 M  | train
# (_train_tune pid=3072) 4 | out          | Linear        | 7.2 K  | train
# (_train_tune pid=3072) -------------------------------------------------------
# (_train_tune pid=3072) 2.1 M     Trainable params
# (_train_tune pid=3072) 0         Non-trainable params
# (_train_tune pid=3072) 2.1 M     Total params
# (_train_tune pid=3072) 8.487     Total estimated model params size (MB)
# (_train_tune pid=3072) 8         Modules in train mode
# (_train_tune pid=3072) 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=25.00, train_loss_epoch=25.00]
# Epoch 11: 100%|██████████| 1/1 [00:00<00:00, 91.89it/s, v_num=0, train_loss_step=26.80, train_loss_epoch=26.80]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=26.80, train_loss_epoch=26.80]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 151.88it/s, v_num=0, train_loss_step=20.10, train_loss_epoch=20.10]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 110.22it/s, v_num=0, train_loss_step=20.30, train_loss_epoch=20.10]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=20.30, train_loss_epoch=20.30]
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.00, train_loss_epoch=18.00]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 124.31it/s, v_num=0, train_loss_step=16.00, train_loss_epoch=16.20]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.00, train_loss_epoch=16.00]
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.60, train_loss_epoch=14.60]
# Epoch 65: 100%|██████████| 1/1 [00:00<00:00, 123.21it/s, v_num=0, train_loss_step=13.10, train_loss_epoch=13.10]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.10, train_loss_epoch=13.10]
# Epoch 77: 100%|██████████| 1/1 [00:00<00:00, 112.59it/s, v_num=0, train_loss_step=12.40, train_loss_epoch=12.40]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.40, train_loss_epoch=12.40]
# Epoch 90: 100%|██████████| 1/1 [00:00<00:00, 165.39it/s, v_num=0, train_loss_step=12.00, train_loss_epoch=12.00]
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.20, train_loss_epoch=12.20]
# (_train_tune pid=3072) `Trainer.fit` stopped: `max_steps=100` reached.
# 2025-07-23 14:53:54,630	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 107.84it/s, v_num=0, train_loss_step=11.80, train_loss_epoch=12.10]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 253.22it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 33.84it/s, v_num=0, train_loss_step=11.80, train_loss_epoch=11.80, valid_loss=9.220]
# (_train_tune pid=3182) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=3182) Seed set to 1
# (_train_tune pid=3182) GPU available: True (cuda), used: True
# (_train_tune pid=3182) TPU available: False, using: 0 TPU cores
# (_train_tune pid=3182) HPU available: False, using: 0 HPUs
# (_train_tune pid=3182) 2025-07-23 14:54:05.093402: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=3182) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=3182) E0000 00:00:1753282445.122902    3258 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=3182) E0000 00:00:1753282445.131279    3258 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=3182) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=3182)
# (_train_tune pid=3182)   | Name         | Type          | Params | Mode
# (_train_tune pid=3182) -------------------------------------------------------
# (_train_tune pid=3182) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=3182) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=3182) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=3182) 3 | mlp          | ModuleList    | 270 K  | train
# (_train_tune pid=3182) 4 | out          | Linear        | 3.6 K  | train
# (_train_tune pid=3182) -------------------------------------------------------
# (_train_tune pid=3182) 273 K     Trainable params
# (_train_tune pid=3182) 0         Non-trainable params
# (_train_tune pid=3182) 273 K     Total params
# (_train_tune pid=3182) 1.096     Total estimated model params size (MB)
# (_train_tune pid=3182) 7         Modules in train mode
# (_train_tune pid=3182) 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.70, train_loss_epoch=37.70]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=29.80, train_loss_epoch=29.80]
# Epoch 26: 100%|██████████| 1/1 [00:00<00:00, 128.17it/s, v_num=0, train_loss_step=29.60, train_loss_epoch=29.80]
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=29.60, train_loss_epoch=29.60]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=22.40, train_loss_epoch=22.40]
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=19.30, train_loss_epoch=19.30]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.30, train_loss_epoch=18.30]
# 2025-07-23 14:54:08,811	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=17.30, train_loss_epoch=17.30]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=17.00, train_loss_epoch=17.00]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 189.38it/s, v_num=0, train_loss_step=16.50, train_loss_epoch=17.10]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 388.51it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 48.23it/s, v_num=0, train_loss_step=16.50, train_loss_epoch=16.50, valid_loss=12.30]
# (_train_tune pid=3182) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=3286) GPU available: True (cuda), used: True
# (_train_tune pid=3286) TPU available: False, using: 0 TPU cores
# (_train_tune pid=3286) HPU available: False, using: 0 HPUs
# (_train_tune pid=3286) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=3286) Seed set to 1
# (_train_tune pid=3286) 2025-07-23 14:54:19.162148: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=3286) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=3286) E0000 00:00:1753282459.185414    3362 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=3286) E0000 00:00:1753282459.194742    3362 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=3286) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=3286)
# (_train_tune pid=3286)   | Name         | Type          | Params | Mode
# (_train_tune pid=3286) -------------------------------------------------------
# (_train_tune pid=3286) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=3286) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=3286) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=3286) 3 | mlp          | ModuleList    | 532 K  | train
# (_train_tune pid=3286) 4 | out          | Linear        | 3.6 K  | train
# (_train_tune pid=3286) -------------------------------------------------------
# (_train_tune pid=3286) 536 K     Trainable params
# (_train_tune pid=3286) 0         Non-trainable params
# (_train_tune pid=3286) 536 K     Total params
# (_train_tune pid=3286) 2.146     Total estimated model params size (MB)
# (_train_tune pid=3286) 8         Modules in train mode
# (_train_tune pid=3286) 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.80, train_loss_epoch=16.80]
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.10, train_loss_epoch=14.10]
# Epoch 39: 100%|██████████| 1/1 [00:00<00:00, 149.43it/s, v_num=0, train_loss_step=13.20, train_loss_epoch=13.20]
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.50, train_loss_epoch=12.50]
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.40, train_loss_epoch=12.40]
# Epoch 78: 100%|██████████| 1/1 [00:00<00:00, 160.47it/s, v_num=0, train_loss_step=11.90, train_loss_epoch=11.60]
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=11.90, train_loss_epoch=11.90]
# 2025-07-23 14:54:23,160	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 92: 100%|██████████| 1/1 [00:00<00:00, 122.86it/s, v_num=0, train_loss_step=11.60, train_loss_epoch=11.30]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=11.60, train_loss_epoch=11.60]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 167.92it/s, v_num=0, train_loss_step=11.20, train_loss_epoch=11.50]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 413.23it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 46.19it/s, v_num=0, train_loss_step=11.20, train_loss_epoch=11.20, valid_loss=9.360]
# (_train_tune pid=3286) `Trainer.fit` stopped: `max_steps=100` reached.
# (_train_tune pid=3397) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=3397) Seed set to 1
# (_train_tune pid=3397) GPU available: True (cuda), used: True
# (_train_tune pid=3397) TPU available: False, using: 0 TPU cores
# (_train_tune pid=3397) HPU available: False, using: 0 HPUs
# (_train_tune pid=3397) 2025-07-23 14:54:34.092265: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=3397) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=3397) E0000 00:00:1753282474.117469    3472 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=3397) E0000 00:00:1753282474.125118    3472 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=3397) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=3397)
# (_train_tune pid=3397)   | Name         | Type          | Params | Mode
# (_train_tune pid=3397) -------------------------------------------------------
# (_train_tune pid=3397) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=3397) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=3397) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=3397) 3 | mlp          | ModuleList    | 2.1 M  | train
# (_train_tune pid=3397) 4 | out          | Linear        | 7.2 K  | train
# (_train_tune pid=3397) -------------------------------------------------------
# (_train_tune pid=3397) 2.1 M     Trainable params
# (_train_tune pid=3397) 0         Non-trainable params
# (_train_tune pid=3397) 2.1 M     Total params
# (_train_tune pid=3397) 8.458     Total estimated model params size (MB)
# (_train_tune pid=3397) 8         Modules in train mode
# (_train_tune pid=3397) 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=53.40, train_loss_epoch=53.40]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=21.60, train_loss_epoch=21.60]
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=19.10, train_loss_epoch=19.10]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 93.05it/s, v_num=0, train_loss_step=16.10, train_loss_epoch=16.10]
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.40, train_loss_epoch=15.40]
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.40, train_loss_epoch=14.40]
# Epoch 56: 100%|██████████| 1/1 [00:00<00:00, 132.03it/s, v_num=0, train_loss_step=13.80, train_loss_epoch=13.80]
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.10, train_loss_epoch=13.10]
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=13.20, train_loss_epoch=13.20]
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.50, train_loss_epoch=12.50]
# (_train_tune pid=3397) `Trainer.fit` stopped: `max_steps=100` reached.
# 2025-07-23 14:54:38,607	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.40, train_loss_epoch=12.40]
# Epoch 91: 100%|██████████| 1/1 [00:00<00:00, 67.53it/s, v_num=0, train_loss_step=12.70, train_loss_epoch=12.40]
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=12.70, train_loss_epoch=12.70]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 109.52it/s, v_num=0, train_loss_step=12.30, train_loss_epoch=12.50]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 329.87it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 34.43it/s, v_num=0, train_loss_step=12.30, train_loss_epoch=12.30, valid_loss=10.90]
# (_train_tune pid=3501) /usr/local/lib/python3.11/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=3501) Seed set to 1
# (_train_tune pid=3501) GPU available: True (cuda), used: True
# (_train_tune pid=3501) TPU available: False, using: 0 TPU cores
# (_train_tune pid=3501) HPU available: False, using: 0 HPUs
# (_train_tune pid=3501) 2025-07-23 14:54:49.427649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=3501) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=3501) E0000 00:00:1753282489.452209    3584 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=3501) E0000 00:00:1753282489.459539    3584 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=3501) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=3501)
# (_train_tune pid=3501)   | Name         | Type          | Params | Mode
# (_train_tune pid=3501) -------------------------------------------------------
# (_train_tune pid=3501) 0 | loss         | MAE           | 0      | train
# (_train_tune pid=3501) 1 | padder_train | ConstantPad1d | 0      | train
# (_train_tune pid=3501) 2 | scaler       | TemporalNorm  | 0      | train
# (_train_tune pid=3501) 3 | mlp          | ModuleList    | 529 K  | train
# (_train_tune pid=3501) 4 | out          | Linear        | 3.6 K  | train
# (_train_tune pid=3501) -------------------------------------------------------
# (_train_tune pid=3501) 532 K     Trainable params
# (_train_tune pid=3501) 0         Non-trainable params
# (_train_tune pid=3501) 532 K     Total params
# (_train_tune pid=3501) 2.132     Total estimated model params size (MB)
# (_train_tune pid=3501) 8         Modules in train mode
# (_train_tune pid=3501) 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=368.0, train_loss_epoch=368.0]
# Epoch 2: 100%|██████████| 1/1 [00:00<00:00, 130.29it/s, v_num=0, train_loss_step=368.0, train_loss_epoch=368.0]
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=24.80, train_loss_epoch=24.80]
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=22.80, train_loss_epoch=22.80]
# Epoch 16: 100%|██████████| 1/1 [00:00<00:00, 143.69it/s, v_num=0, train_loss_step=20.70, train_loss_epoch=22.80]
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=20.70, train_loss_epoch=20.70]
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=19.60, train_loss_epoch=19.60]
# Epoch 30: 100%|██████████| 1/1 [00:00<00:00, 130.68it/s, v_num=0, train_loss_step=18.70, train_loss_epoch=18.70]
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=18.70, train_loss_epoch=18.70]
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=16.80, train_loss_epoch=16.80]
# Epoch 44: 100%|██████████| 1/1 [00:00<00:00, 105.94it/s, v_num=0, train_loss_step=17.00, train_loss_epoch=17.00]
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=17.00, train_loss_epoch=17.00]
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.80, train_loss_epoch=15.80]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=15.20, train_loss_epoch=15.20]
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.40, train_loss_epoch=14.40]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 144.25it/s, v_num=0, train_loss_step=14.60, train_loss_epoch=14.40]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 132.09it/s, v_num=0, train_loss_step=14.60, train_loss_epoch=14.60]
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=14.60, train_loss_epoch=14.60]
# 2025-07-23 14:54:54,325	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'loss': ('__ref_ph', 'de895953'), 'valid_loss': ('__ref_ph', '004b9a7a')}
# 2025-07-23 14:54:54,339	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/_train_tune_2025-07-23_14-52-13' in 0.0103s.
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# (_train_tune pid=3501) `Trainer.fit` stopped: `max_steps=100` reached.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | eval
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | mlp          | ModuleList    | 2.1 M  | train
# 4 | out          | Linear        | 7.2 K  | train
# -------------------------------------------------------
# 2.1 M     Trainable params
# 0         Non-trainable params
# 2.1 M     Total params
# 8.487     Total estimated model params size (MB)
# 7         Modules in train mode
# 1         Modules in eval mode
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 145.55it/s, v_num=0, train_loss_step=14.20, train_loss_epoch=14.20]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 138.24it/s, v_num=0, train_loss_step=14.00, train_loss_epoch=14.20]
#
# (_train_tune pid=3501)
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 361.73it/s]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 38.56it/s, v_num=0, train_loss_step=14.00, train_loss_epoch=14.00, valid_loss=10.20]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=100` reached.

# %%
results = nf.models[0].results.get_dataframe()

config_cols = [col for col in results.columns if col.startswith('config')]
columns_to_keep = ['loss', 'train_loss'] + config_cols
existing_columns = [col for col in columns_to_keep if col in results.columns]
filtered_results = results[existing_columns]
best_runs = filtered_results.sort_values('loss', ascending=True).head(5)
best_runs
# Out:
#         loss  train_loss  config/max_steps  config/input_size  \
# 5   9.223154   11.841568               100                 14
# 7   9.360003   11.244987               100                 14
# 1   9.371546   13.951206               100                 14
# 2   9.767621   12.480261               100                 14
# 9  10.203548   14.039692               100                  7
#
#    config/hidden_size  config/num_layers  config/learning_rate  config/h  \
# 5                1024                  3              0.002692         7
# 7                 512                  3              0.001725         7
# 1                1024                  3              0.000039         7
# 2                1024                  3              0.018668         7
# 9                 512                  3              0.009526         7
#
#   config/loss config/valid_loss
# 5       MAE()             MAE()
# 7       MAE()             MAE()
# 1       MAE()             MAE()
# 2       MAE()             MAE()
# 9       MAE()             MAE()
