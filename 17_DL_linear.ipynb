# %% [markdown]
# # Deep learning - Linear models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, RNN

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
train_df = pd.read_csv('data/train.csv')
val_df = pd.read_csv('data/val.csv')
test_df = pd.read_csv('data/test.csv')

# %%
train_df.head()
# Out:
#        HUFL      HULL      MUFL      MULL      LUFL      LULL        OT  \
# 0  0.588227  0.454943  0.599461  0.473673  0.556576  0.613765  0.691018
# 1  0.585130  0.459449  0.596738  0.471006  0.550279  0.620783  0.636233
# 2  0.572743  0.436920  0.591319  0.465748  0.512595  0.586144  0.636233
# 3  0.571194  0.450437  0.591319  0.468414  0.515693  0.599955  0.581468
# 4  0.577388  0.450437  0.596738  0.473673  0.521990  0.599955  0.519656
#
#     day_sin       day_cos  year_sin  year_cos
# 0  0.866025  5.000000e-01  0.010486 -0.999945
# 1  0.965926  2.588190e-01  0.009770 -0.999952
# 2  1.000000  7.440628e-12  0.009053 -0.999959
# 3  0.965926 -2.588190e-01  0.008336 -0.999965
# 4  0.866025 -5.000000e-01  0.007619 -0.999971

# %%
def format_timeseries_data(df, input_length, output_length, target_names):
    
    if target_names is not None:
        target_indices = {name: i for i, name in enumerate(target_names)}
    col_indices = {name: i for i, name in enumerate(df.columns)}
    
    total_length = input_length + output_length
    
    input_slice = slice(0, input_length)
    output_slice = slice(input_length, None)
    
    data = np.array(df, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=total_length,
        sequence_stride=1,
        shuffle=False,
        batch_size=32
    )
    
    def split_to_input_output(x):
            
        inputs = x[:, input_slice, :]
        outputs = x[:, output_slice, :]
        
        if target_names is not None:
            outputs = tf.stack(
                [outputs[:,:,col_indices[name]] for name in target_names],
                axis=-1
            )

        inputs.set_shape([None, input_length, None])
        outputs.set_shape([None, output_length, None])
    
        return inputs, outputs
    
    ds = ds.map(split_to_input_output)
    
    return ds

# %%
def train_model(model, train_ds, val_ds, patience=5, max_epochs=50):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    return history

# %%
MULL_max_train = 7.568999767303468
MULL_min_train = -5.934000015258789
MULL_max_test = 4.690999984741211
MULL_min_test = -3.3399999141693115

OT_max_train = 46.00699996948242
OT_min_train = -4.079999923706056
OT_max_test = 17.165000915527347
OT_min_test = 3.025000095367432

# %% [markdown]
# ## Single-step model

# %%
train_ds_ss = format_timeseries_data(train_df, 1, 1, ['OT'])
val_ds_ss = format_timeseries_data(val_df, 1, 1, ['OT'])
test_ds_ss = format_timeseries_data(test_df, 1, 1, ['OT'])

ss_sample_batch = next(iter(test_ds_ss))

# %%
ss_linear = Sequential([
    Dense(units=1)
])

ss_linear_history = train_model(ss_linear, train_ds_ss, val_ds_ss)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 2s 2ms/step - loss: 0.1654 - mean_absolute_error: 0.3268 - val_loss: 0.0671 - val_mean_absolute_error: 0.2249
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0419 - mean_absolute_error: 0.1686 - val_loss: 0.0297 - val_mean_absolute_error: 0.1544
# Epoch 3/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1104 - val_loss: 0.0132 - val_mean_absolute_error: 0.0984
# Epoch 4/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0128 - mean_absolute_error: 0.0890 - val_loss: 0.0051 - val_mean_absolute_error: 0.0576
# Epoch 5/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0104 - mean_absolute_error: 0.0780 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0087 - mean_absolute_error: 0.0696 - val_loss: 0.0047 - val_mean_absolute_error: 0.0526
# Epoch 7/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0073 - mean_absolute_error: 0.0634 - val_loss: 0.0041 - val_mean_absolute_error: 0.0493
# Epoch 8/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0588 - val_loss: 0.0032 - val_mean_absolute_error: 0.0439
# Epoch 9/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0551 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 10/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0375
# Epoch 11/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0040 - mean_absolute_error: 0.0480 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 12/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0445 - val_loss: 0.0018 - val_mean_absolute_error: 0.0333
# Epoch 13/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0029 - mean_absolute_error: 0.0411 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 14/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 15/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 16/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 8.7467e-04 - val_mean_absolute_error: 0.0234
# Epoch 17/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - val_loss: 7.1501e-04 - val_mean_absolute_error: 0.0211
# Epoch 18/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 5.8000e-04 - val_mean_absolute_error: 0.0189
# Epoch 19/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0249 - val_loss: 4.6851e-04 - val_mean_absolute_error: 0.0169
# Epoch 20/50
# 382/382 [==============================] - 1s 1ms/step - loss: 9.3886e-04 - mean_absolute_error: 0.0229 - val_loss: 3.8049e-04 - val_mean_absolute_error: 0.0152
# Epoch 21/50
# 382/382 [==============================] - 0s 1ms/step - loss: 8.1608e-04 - mean_absolute_error: 0.0211 - val_loss: 3.1382e-04 - val_mean_absolute_error: 0.0137
# Epoch 22/50
# 382/382 [==============================] - 0s 1ms/step - loss: 7.2068e-04 - mean_absolute_error: 0.0197 - val_loss: 2.6332e-04 - val_mean_absolute_error: 0.0125
# Epoch 23/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.4817e-04 - mean_absolute_error: 0.0186 - val_loss: 2.2484e-04 - val_mean_absolute_error: 0.0115
# Epoch 24/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.9441e-04 - mean_absolute_error: 0.0177 - val_loss: 2.0320e-04 - val_mean_absolute_error: 0.0109
# Epoch 25/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.5563e-04 - mean_absolute_error: 0.0170 - val_loss: 2.0628e-04 - val_mean_absolute_error: 0.0110
# Epoch 26/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.2844e-04 - mean_absolute_error: 0.0165 - val_loss: 2.2475e-04 - val_mean_absolute_error: 0.0116
# Epoch 27/50
# 382/382 [==============================] - 1s 2ms/step - loss: 5.0973e-04 - mean_absolute_error: 0.0162 - val_loss: 2.3362e-04 - val_mean_absolute_error: 0.0119
# Epoch 28/50
# 382/382 [==============================] - 1s 2ms/step - loss: 4.9662e-04 - mean_absolute_error: 0.0160 - val_loss: 2.2154e-04 - val_mean_absolute_error: 0.0116
# Epoch 29/50
# 382/382 [==============================] - 1s 2ms/step - loss: 4.8686e-04 - mean_absolute_error: 0.0158 - val_loss: 2.0022e-04 - val_mean_absolute_error: 0.0109
# Epoch 30/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.7927e-04 - mean_absolute_error: 0.0157 - val_loss: 1.8344e-04 - val_mean_absolute_error: 0.0103
# Epoch 31/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.7350e-04 - mean_absolute_error: 0.0156 - val_loss: 1.7430e-04 - val_mean_absolute_error: 0.0099
# Epoch 32/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.6929e-04 - mean_absolute_error: 0.0155 - val_loss: 1.7036e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.6621e-04 - mean_absolute_error: 0.0154 - val_loss: 1.6938e-04 - val_mean_absolute_error: 0.0097
# Epoch 34/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.6380e-04 - mean_absolute_error: 0.0154 - val_loss: 1.6978e-04 - val_mean_absolute_error: 0.0097
# Epoch 35/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.6180e-04 - mean_absolute_error: 0.0153 - val_loss: 1.7025e-04 - val_mean_absolute_error: 0.0097
# Epoch 36/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.6009e-04 - mean_absolute_error: 0.0153 - val_loss: 1.7021e-04 - val_mean_absolute_error: 0.0097
# Epoch 37/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.5860e-04 - mean_absolute_error: 0.0152 - val_loss: 1.6982e-04 - val_mean_absolute_error: 0.0097
# Epoch 38/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5723e-04 - mean_absolute_error: 0.0152 - val_loss: 1.6935e-04 - val_mean_absolute_error: 0.0096
# Epoch 39/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5591e-04 - mean_absolute_error: 0.0152 - val_loss: 1.6882e-04 - val_mean_absolute_error: 0.0096
# Epoch 40/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5459e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6815e-04 - val_mean_absolute_error: 0.0096
# Epoch 41/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5330e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6738e-04 - val_mean_absolute_error: 0.0096
# Epoch 42/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5204e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6664e-04 - val_mean_absolute_error: 0.0095
# Epoch 43/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.5082e-04 - mean_absolute_error: 0.0150 - val_loss: 1.6599e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4960e-04 - mean_absolute_error: 0.0150 - val_loss: 1.6538e-04 - val_mean_absolute_error: 0.0095
# Epoch 45/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4841e-04 - mean_absolute_error: 0.0150 - val_loss: 1.6477e-04 - val_mean_absolute_error: 0.0095
# Epoch 46/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4723e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6414e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4609e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6353e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4498e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6296e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4389e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6242e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 382/382 [==============================] - 0s 1ms/step - loss: 4.4282e-04 - mean_absolute_error: 0.0148 - val_loss: 1.6187e-04 - val_mean_absolute_error: 0.0094

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss')
    ax1.legend(loc='best')

    ax2.plot(history.history['mean_absolute_error'], label='Train')
    ax2.plot(history.history['val_mean_absolute_error'], label='Validation')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('MAE')
    ax2.set_title('Mean absolute error')
    ax2.legend(loc='best')

    plt.tight_layout()

# %%
plot_history(ss_linear_history)

# %%
def plot_predictions(model, sample_batch, model_type):
    
    inputs, outputs = sample_batch
    preds = model(inputs)
    
    if model_type == 'single_step':      

        fig, ax = plt.subplots()

        actual_scaled = outputs.numpy().flatten()
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train
        
        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_step':

        fig, ax = plt.subplots()
        
        actual_scaled = outputs.numpy().flatten()[:48]
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()[:48]
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_output':
        
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
        
        OT_actual_scaled = outputs.numpy().flatten()[0::2]
        OT_actual = OT_actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        OT_predictions_scaled = preds.numpy().flatten()[0::2]
        OT_predictions = OT_predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        MULL_actual_scaled = outputs.numpy().flatten()[1::2]
        MULL_actual = MULL_actual_scaled * (MULL_max_test - MULL_min_test) + MULL_min_test
        
        MULL_predictions_scaled = preds.numpy().flatten()[1::2]
        MULL_predictions = MULL_predictions_scaled * (MULL_max_train - MULL_min_train) + MULL_min_train
        
        ax1.plot(OT_actual, label='Actual')
        ax1.plot(OT_predictions, label='Predicted')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Oil temperature')
        ax1.legend(loc='best')
        ax1.set_title('Predictions on a sample batch')
        
        ax2.plot(MULL_actual, label='Actual')
        ax2.plot(MULL_predictions, label='Predicted')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('MULL')
        ax2.legend(loc='best')
        
    plt.tight_layout()

# %%
plot_predictions(ss_linear, ss_sample_batch, 'single_step')

# %% [markdown]
# ## Multi-step model

# %%
train_ds_ms = format_timeseries_data(train_df, 24, 24, ['OT'])
val_ds_ms = format_timeseries_data(val_df, 24, 24, ['OT'])
test_ds_ms = format_timeseries_data(test_df, 24, 24, ['OT'])

ms_sample_batch = next(iter(test_ds_ms))

# %%
ms_linear = Sequential([
    Dense(units=1)
])

ms_linear_history = train_model(ms_linear, train_ds_ms, val_ds_ms)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 1s 2ms/step - loss: 0.2100 - mean_absolute_error: 0.3621 - val_loss: 0.0767 - val_mean_absolute_error: 0.2417
# Epoch 2/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0488 - mean_absolute_error: 0.1815 - val_loss: 0.0281 - val_mean_absolute_error: 0.1357
# Epoch 3/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0263 - mean_absolute_error: 0.1277 - val_loss: 0.0245 - val_mean_absolute_error: 0.1241
# Epoch 4/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0205 - mean_absolute_error: 0.1114 - val_loss: 0.0286 - val_mean_absolute_error: 0.1375
# Epoch 5/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.1023 - val_loss: 0.0291 - val_mean_absolute_error: 0.1407
# Epoch 6/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0144 - mean_absolute_error: 0.0944 - val_loss: 0.0255 - val_mean_absolute_error: 0.1319
# Epoch 7/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0876 - val_loss: 0.0209 - val_mean_absolute_error: 0.1187
# Epoch 8/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0107 - mean_absolute_error: 0.0819 - val_loss: 0.0170 - val_mean_absolute_error: 0.1065
# Epoch 9/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0095 - mean_absolute_error: 0.0770 - val_loss: 0.0141 - val_mean_absolute_error: 0.0965
# Epoch 10/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0085 - mean_absolute_error: 0.0729 - val_loss: 0.0118 - val_mean_absolute_error: 0.0881
# Epoch 11/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0077 - mean_absolute_error: 0.0693 - val_loss: 0.0099 - val_mean_absolute_error: 0.0802
# Epoch 12/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0071 - mean_absolute_error: 0.0662 - val_loss: 0.0081 - val_mean_absolute_error: 0.0724
# Epoch 13/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0066 - mean_absolute_error: 0.0636 - val_loss: 0.0066 - val_mean_absolute_error: 0.0651
# Epoch 14/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0054 - val_mean_absolute_error: 0.0588
# Epoch 15/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0596 - val_loss: 0.0045 - val_mean_absolute_error: 0.0534
# Epoch 16/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0056 - mean_absolute_error: 0.0581 - val_loss: 0.0038 - val_mean_absolute_error: 0.0491
# Epoch 17/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0054 - mean_absolute_error: 0.0567 - val_loss: 0.0033 - val_mean_absolute_error: 0.0455
# Epoch 18/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0052 - mean_absolute_error: 0.0555 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 19/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0050 - mean_absolute_error: 0.0545 - val_loss: 0.0026 - val_mean_absolute_error: 0.0403
# Epoch 20/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0536 - val_loss: 0.0024 - val_mean_absolute_error: 0.0386
# Epoch 21/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0529 - val_loss: 0.0022 - val_mean_absolute_error: 0.0372
# Epoch 22/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0046 - mean_absolute_error: 0.0522 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 23/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0516 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 24/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0512 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 25/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0507 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 26/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0043 - mean_absolute_error: 0.0504 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 27/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0043 - mean_absolute_error: 0.0501 - val_loss: 0.0018 - val_mean_absolute_error: 0.0343
# Epoch 28/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0498 - val_loss: 0.0018 - val_mean_absolute_error: 0.0342
# Epoch 29/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0496 - val_loss: 0.0018 - val_mean_absolute_error: 0.0342
# Epoch 30/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0042 - mean_absolute_error: 0.0494 - val_loss: 0.0018 - val_mean_absolute_error: 0.0343
# Epoch 31/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0492 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 32/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0491 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 33/50
# 380/380 [==============================] - 1s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0490 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 34/50
# 380/380 [==============================] - 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0489 - val_loss: 0.0018 - val_mean_absolute_error: 0.0347

# %%
plot_history(ms_linear_history)

# %%
plot_predictions(ms_linear, ms_sample_batch, 'multi_step')

# %% [markdown]
# ## Multi_output

# %%
train_ds_mo = format_timeseries_data(train_df, 1, 1, ['OT', 'MULL'])
val_ds_mo = format_timeseries_data(val_df, 1, 1, ['OT', 'MULL'])
test_ds_mo = format_timeseries_data(test_df, 1, 1, ['OT', 'MULL'])

mo_sample_batch = next(iter(test_ds_mo))

# %%
mo_linear = Sequential([
    Dense(units=2)
])

mo_linear_history = train_model(mo_linear, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 1s 2ms/step - loss: 0.2673 - mean_absolute_error: 0.4178 - val_loss: 0.0487 - val_mean_absolute_error: 0.1801
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0541 - mean_absolute_error: 0.1802 - val_loss: 0.0206 - val_mean_absolute_error: 0.1121
# Epoch 3/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0334 - mean_absolute_error: 0.1403 - val_loss: 0.0152 - val_mean_absolute_error: 0.0962
# Epoch 4/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0259 - mean_absolute_error: 0.1244 - val_loss: 0.0172 - val_mean_absolute_error: 0.1038
# Epoch 5/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0216 - mean_absolute_error: 0.1133 - val_loss: 0.0200 - val_mean_absolute_error: 0.1137
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.1043 - val_loss: 0.0199 - val_mean_absolute_error: 0.1143
# Epoch 7/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_absolute_error: 0.0969 - val_loss: 0.0170 - val_mean_absolute_error: 0.1058
# Epoch 8/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0139 - mean_absolute_error: 0.0907 - val_loss: 0.0134 - val_mean_absolute_error: 0.0933
# Epoch 9/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0123 - mean_absolute_error: 0.0852 - val_loss: 0.0103 - val_mean_absolute_error: 0.0814
# Epoch 10/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0108 - mean_absolute_error: 0.0802 - val_loss: 0.0081 - val_mean_absolute_error: 0.0719
# Epoch 11/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0096 - mean_absolute_error: 0.0755 - val_loss: 0.0066 - val_mean_absolute_error: 0.0647
# Epoch 12/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0085 - mean_absolute_error: 0.0711 - val_loss: 0.0055 - val_mean_absolute_error: 0.0589
# Epoch 13/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0076 - mean_absolute_error: 0.0670 - val_loss: 0.0047 - val_mean_absolute_error: 0.0541
# Epoch 14/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0068 - mean_absolute_error: 0.0633 - val_loss: 0.0040 - val_mean_absolute_error: 0.0500
# Epoch 15/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0599 - val_loss: 0.0035 - val_mean_absolute_error: 0.0466
# Epoch 16/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0055 - mean_absolute_error: 0.0569 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 17/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0049 - mean_absolute_error: 0.0540 - val_loss: 0.0028 - val_mean_absolute_error: 0.0414
# Epoch 18/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0514 - val_loss: 0.0026 - val_mean_absolute_error: 0.0393
# Epoch 19/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0489 - val_loss: 0.0024 - val_mean_absolute_error: 0.0376
# Epoch 20/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0466 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 21/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0445 - val_loss: 0.0021 - val_mean_absolute_error: 0.0347
# Epoch 22/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0426 - val_loss: 0.0020 - val_mean_absolute_error: 0.0335
# Epoch 23/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0019 - val_mean_absolute_error: 0.0324
# Epoch 24/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0391 - val_loss: 0.0018 - val_mean_absolute_error: 0.0314
# Epoch 25/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0376 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
# Epoch 26/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0362 - val_loss: 0.0017 - val_mean_absolute_error: 0.0295
# Epoch 27/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0349 - val_loss: 0.0016 - val_mean_absolute_error: 0.0286
# Epoch 28/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - val_loss: 0.0016 - val_mean_absolute_error: 0.0278
# Epoch 29/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0328 - val_loss: 0.0015 - val_mean_absolute_error: 0.0271
# Epoch 30/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0319 - val_loss: 0.0015 - val_mean_absolute_error: 0.0265
# Epoch 31/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0312 - val_loss: 0.0015 - val_mean_absolute_error: 0.0260
# Epoch 32/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256
# Epoch 33/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0300 - val_loss: 0.0014 - val_mean_absolute_error: 0.0253
# Epoch 34/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0295 - val_loss: 0.0014 - val_mean_absolute_error: 0.0251
# Epoch 35/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - val_loss: 0.0014 - val_mean_absolute_error: 0.0249
# Epoch 36/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0288 - val_loss: 0.0014 - val_mean_absolute_error: 0.0247
# Epoch 37/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0285 - val_loss: 0.0014 - val_mean_absolute_error: 0.0244
# Epoch 38/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0283 - val_loss: 0.0014 - val_mean_absolute_error: 0.0242
# Epoch 39/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0280 - val_loss: 0.0014 - val_mean_absolute_error: 0.0240
# Epoch 40/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0278 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237
# Epoch 41/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0277 - val_loss: 0.0013 - val_mean_absolute_error: 0.0236
# Epoch 42/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0276 - val_loss: 0.0013 - val_mean_absolute_error: 0.0236
# Epoch 43/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0274 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237
# Epoch 44/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0274 - val_loss: 0.0014 - val_mean_absolute_error: 0.0240
# Epoch 45/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0273 - val_loss: 0.0014 - val_mean_absolute_error: 0.0243
# Epoch 46/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0014 - val_mean_absolute_error: 0.0246
# Epoch 47/50
# 382/382 [==============================] - 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0272 - val_loss: 0.0014 - val_mean_absolute_error: 0.0248

# %%
plot_history(mo_linear_history)

# %%
plot_predictions(mo_linear, mo_sample_batch, 'multi_output')

# %% [markdown]
# ## Evaluation

# %%
mae_linear_ss = ss_linear.evaluate(test_ds_ss)[1]
mae_linear_ms = ms_linear.evaluate(test_ds_ms)[1]
mae_linear_mo = mo_linear.evaluate(test_ds_mo)[1]
# Out:
# 55/55 [==============================] - 0s 908us/step - loss: 0.0022 - mean_absolute_error: 0.0318
# 53/53 [==============================] - 0s 923us/step - loss: 0.0235 - mean_absolute_error: 0.1229
# 55/55 [==============================] - 0s 889us/step - loss: 0.0049 - mean_absolute_error: 0.0495
