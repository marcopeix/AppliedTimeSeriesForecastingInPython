# %% [markdown]
# # Deep learning - Deep neural networks

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, RNN

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["figure.figsize"] = (9,6)

# %%
np.random.seed(42)
tf.random.set_seed(42)
tf.keras.utils.set_random_seed(42)

# %%
train_df = pd.read_csv('data/train.csv')
val_df = pd.read_csv('data/val.csv')
test_df = pd.read_csv('data/test.csv')

# %%
def format_timeseries_data(df, input_length, output_length, target_names):
    
    if target_names is not None:
        target_indices = {name: i for i, name in enumerate(target_names)}
    col_indices = {name: i for i, name in enumerate(df.columns)}
    
    total_length = input_length + output_length
    
    input_slice = slice(0, input_length)
    output_slice = slice(input_length, None)
    
    data = np.array(df, dtype=np.float32)
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=total_length,
        sequence_stride=1,
        shuffle=False,
        batch_size=32
    )
    
    def split_to_input_output(x):
            
        inputs = x[:, input_slice, :]
        outputs = x[:, output_slice, :]
        
        if target_names is not None:
            outputs = tf.stack(
                [outputs[:,:,col_indices[name]] for name in target_names],
                axis=-1
            )

        inputs.set_shape([None, input_length, None])
        outputs.set_shape([None, output_length, None])
    
        return inputs, outputs
    
    ds = ds.map(split_to_input_output)
    
    return ds

# %%
def train_model(model, train_ds, val_ds, patience=5, max_epochs=50):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    return history

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

    ax1.plot(history.history['loss'], label='Train')
    ax1.plot(history.history['val_loss'], label='Validation')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.set_title('Loss')
    ax1.legend(loc='best')

    ax2.plot(history.history['mean_absolute_error'], label='Train')
    ax2.plot(history.history['val_mean_absolute_error'], label='Validation')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('MAE')
    ax2.set_title('Mean absolute error')
    ax2.legend(loc='best')

    plt.tight_layout()

# %%
def plot_predictions(model, sample_batch, model_type):
    
    inputs, outputs = sample_batch
    preds = model(inputs)
    
    if model_type == 'single_step':      

        fig, ax = plt.subplots()

        actual_scaled = outputs.numpy().flatten()
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train
        
        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_step':

        fig, ax = plt.subplots()
        
        actual_scaled = outputs.numpy().flatten()[:48]
        actual = actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        predictions_scaled = preds.numpy().flatten()[:48]
        predictions = predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        ax.plot(actual, label='Actual')
        ax.plot(predictions, label='Predicted')
        ax.set_xlabel('Time steps')
        ax.set_ylabel('Oil temperature')
        ax.set_title('Predictions on a sample batch')
        ax.legend(loc='best')
        
    elif model_type == 'multi_output':
        
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)
        
        OT_actual_scaled = outputs.numpy().flatten()[0::2]
        OT_actual = OT_actual_scaled * (OT_max_test - OT_min_test) + OT_min_test
        
        OT_predictions_scaled = preds.numpy().flatten()[0::2]
        OT_predictions = OT_predictions_scaled * (OT_max_train - OT_min_train) + OT_min_train

        MULL_actual_scaled = outputs.numpy().flatten()[1::2]
        MULL_actual = MULL_actual_scaled * (MULL_max_test - MULL_min_test) + MULL_min_test
        
        MULL_predictions_scaled = preds.numpy().flatten()[1::2]
        MULL_predictions = MULL_predictions_scaled * (MULL_max_train - MULL_min_train) + MULL_min_train
        
        ax1.plot(OT_actual, label='Actual')
        ax1.plot(OT_predictions, label='Predicted')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Oil temperature')
        ax1.legend(loc='best')
        ax1.set_title('Predictions on a sample batch')
        
        ax2.plot(MULL_actual, label='Actual')
        ax2.plot(MULL_predictions, label='Predicted')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('MULL')
        ax2.legend(loc='best')
        
    plt.tight_layout()

# %%
MULL_max_train = 7.568999767303468
MULL_min_train = -5.934000015258789
MULL_max_test = 4.690999984741211
MULL_min_test = -3.3399999141693115

OT_max_train = 46.00699996948242
OT_min_train = -4.079999923706056
OT_max_test = 17.165000915527347
OT_min_test = 3.025000095367432

# %% [markdown]
# ## Single-step model

# %%
train_ds_ss = format_timeseries_data(train_df, 1, 1, ['OT'])
val_ds_ss = format_timeseries_data(val_df, 1, 1, ['OT'])
test_ds_ss = format_timeseries_data(test_df, 1, 1, ['OT'])

ss_sample_batch = next(iter(test_ds_ss))

# %%
ss_dnn = Sequential([
    Dense(32, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

ss_dnn_history = train_model(ss_dnn, train_ds_ss, val_ds_ss)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 1s 2ms/step - loss: 0.0134 - mean_absolute_error: 0.0740 - val_loss: 0.0031 - val_mean_absolute_error: 0.0447
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0039 - mean_absolute_error: 0.0474 - val_loss: 0.0158 - val_mean_absolute_error: 0.1074
# Epoch 3/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0448 - val_mean_absolute_error: 0.1837
# Epoch 4/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0026 - mean_absolute_error: 0.0380 - val_loss: 0.0561 - val_mean_absolute_error: 0.2050
# Epoch 5/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0497 - val_mean_absolute_error: 0.1923
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0308 - val_loss: 0.0418 - val_mean_absolute_error: 0.1757

# %%
plot_history(ss_dnn_history)

# %% [markdown]
# ### Add a learning rate scheduler

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 2:
        return lr
    else:
        return lr * tf.math.exp(-0.1)
    
lr_scheduler = LearningRateScheduler(scheduler)

def train_model(model, train_ds, val_ds, patience=5, max_epochs=50, use_scheduler=False):
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, mode='min')
    
    model.compile(loss=MeanSquaredError(), optimizer=Adam(), metrics=[MeanAbsoluteError()])
    
    history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping])
    
    if use_scheduler == True:
        history = model.fit(train_ds, epochs=max_epochs, validation_data=val_ds, callbacks=[early_stopping, lr_scheduler])
    
    return history

# %%
ss_dnn_history = train_model(ss_dnn, train_ds_ss, val_ds_ss, use_scheduler=True)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 1s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 0.0192 - val_mean_absolute_error: 0.1154
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 0.0132 - val_mean_absolute_error: 0.0941
# Epoch 3/50
# 382/382 [==============================] - 1s 1ms/step - loss: 8.9398e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0123 - val_mean_absolute_error: 0.0900
# Epoch 4/50
# 382/382 [==============================] - 1s 1ms/step - loss: 7.6168e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0104 - val_mean_absolute_error: 0.0792
# Epoch 5/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.9215e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0068 - val_mean_absolute_error: 0.0632
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.4559e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0053 - val_mean_absolute_error: 0.0544
# Epoch 7/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.1081e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0047 - val_mean_absolute_error: 0.0506
# Epoch 8/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.8962e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0051 - val_mean_absolute_error: 0.0520
# Epoch 9/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.6988e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0050 - val_mean_absolute_error: 0.0502
# Epoch 10/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.5654e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0042 - val_mean_absolute_error: 0.0452
# Epoch 11/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.5283e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0034 - val_mean_absolute_error: 0.0404
# Epoch 12/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.5210e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0030 - val_mean_absolute_error: 0.0384
# Epoch 13/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.4908e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0028 - val_mean_absolute_error: 0.0376
# Epoch 14/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.5862e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0020 - val_mean_absolute_error: 0.0327
# Epoch 15/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.4874e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0018 - val_mean_absolute_error: 0.0313
# Epoch 16/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7353e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 17/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7712e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 18/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7385e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 19/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7447e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274
# Epoch 20/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.6099e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0015 - val_mean_absolute_error: 0.0281
# Epoch 21/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.8509e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 22/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7105e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 23/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.1506e-04 - mean_absolute_error: 0.0180 - val_loss: 8.2028e-04 - val_mean_absolute_error: 0.0225
# Epoch 24/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.8508e-04 - mean_absolute_error: 0.0177 - val_loss: 9.9813e-04 - val_mean_absolute_error: 0.0252
# Epoch 25/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.7739e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0015 - val_mean_absolute_error: 0.0316
# Epoch 26/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.0412e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 27/50
# 382/382 [==============================] - 1s 1ms/step - loss: 6.4879e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 28/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.9999e-04 - mean_absolute_error: 0.0177 - val_loss: 8.7459e-04 - val_mean_absolute_error: 0.0237
# Epoch 1/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.9406e-04 - mean_absolute_error: 0.0176 - val_loss: 7.2601e-04 - val_mean_absolute_error: 0.0213 - lr: 0.0010
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.4690e-04 - mean_absolute_error: 0.0169 - val_loss: 5.5396e-04 - val_mean_absolute_error: 0.0186 - lr: 0.0010
# Epoch 3/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.2932e-04 - mean_absolute_error: 0.0167 - val_loss: 5.2451e-04 - val_mean_absolute_error: 0.0180 - lr: 9.0484e-04
# Epoch 4/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.2519e-04 - mean_absolute_error: 0.0166 - val_loss: 5.2299e-04 - val_mean_absolute_error: 0.0179 - lr: 8.1873e-04
# Epoch 5/50
# 382/382 [==============================] - 1s 1ms/step - loss: 5.0749e-04 - mean_absolute_error: 0.0163 - val_loss: 5.2420e-04 - val_mean_absolute_error: 0.0178 - lr: 7.4082e-04
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.9109e-04 - mean_absolute_error: 0.0160 - val_loss: 5.5214e-04 - val_mean_absolute_error: 0.0185 - lr: 6.7032e-04
# Epoch 7/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.8203e-04 - mean_absolute_error: 0.0158 - val_loss: 5.3244e-04 - val_mean_absolute_error: 0.0183 - lr: 6.0653e-04
# Epoch 8/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.6758e-04 - mean_absolute_error: 0.0155 - val_loss: 5.4733e-04 - val_mean_absolute_error: 0.0186 - lr: 5.4881e-04
# Epoch 9/50
# 382/382 [==============================] - 1s 1ms/step - loss: 4.5559e-04 - mean_absolute_error: 0.0152 - val_loss: 5.4813e-04 - val_mean_absolute_error: 0.0187 - lr: 4.9659e-04

# %%
plot_history(ss_dnn_history)

# %%
plot_predictions(ss_dnn, ss_sample_batch, 'single_step')

# %% [markdown]
# ### Evaluation

# %%
ss_mae = [0.0318]
ss_mae.append(ss_dnn.evaluate(test_ds_ss)[1])

x = ['Linear', 'DNN']

fig, ax = plt.subplots()
ax.bar(x, ss_mae, width=0.3)
ax.set_ylabel('MAE')
ax.set_xlabel('Models')
ax.set_ylim(0, max(ss_mae)+0.1)
for index, value in enumerate(ss_mae):
    ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
plt.tight_layout()
# Out:
# 55/55 [==============================] - 0s 984us/step - loss: 0.0067 - mean_absolute_error: 0.0707

# %% [markdown]
# ## Multi-step model

# %%
train_ds_ms = format_timeseries_data(train_df, 24, 24, ['OT'])
val_ds_ms = format_timeseries_data(val_df, 24, 24, ['OT'])
test_ds_ms = format_timeseries_data(test_df, 24, 24, ['OT'])

ms_sample_batch = next(iter(test_ds_ms))

# %%
ms_dnn = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

ms_dnn_history = train_model(ms_dnn, train_ds_ms, val_ds_ms)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 2s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0599 - val_loss: 0.0089 - val_mean_absolute_error: 0.0804
# Epoch 2/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0058 - mean_absolute_error: 0.0573 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499
# Epoch 3/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0521 - val_loss: 0.0036 - val_mean_absolute_error: 0.0468
# Epoch 4/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0517 - val_loss: 0.0058 - val_mean_absolute_error: 0.0597
# Epoch 5/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0528 - val_loss: 0.0050 - val_mean_absolute_error: 0.0545
# Epoch 6/50
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0527 - val_loss: 0.0037 - val_mean_absolute_error: 0.0472
# Epoch 7/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0533 - val_loss: 0.0032 - val_mean_absolute_error: 0.0448
# Epoch 8/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0528 - val_loss: 0.0032 - val_mean_absolute_error: 0.0450
# Epoch 9/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0524 - val_loss: 0.0031 - val_mean_absolute_error: 0.0444
# Epoch 10/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0518 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 11/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0521 - val_loss: 0.0031 - val_mean_absolute_error: 0.0443
# Epoch 12/50
# 380/380 [==============================] - 1s 2ms/step - loss: 0.0046 - mean_absolute_error: 0.0516 - val_loss: 0.0032 - val_mean_absolute_error: 0.0457
# Epoch 13/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0520 - val_loss: 0.0041 - val_mean_absolute_error: 0.0537
# Epoch 14/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0511 - val_loss: 0.0043 - val_mean_absolute_error: 0.0545
# Epoch 15/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0516 - val_loss: 0.0051 - val_mean_absolute_error: 0.0597

# %%
plot_history(ms_dnn_history)

# %%
ms_dnn_history = train_model(ms_dnn, train_ds_ms, val_ds_ms, use_scheduler=True)
# Out:
# Epoch 1/50
# 380/380 [==============================] - 2s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0529 - val_loss: 0.0066 - val_mean_absolute_error: 0.0684
# Epoch 2/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0522 - val_loss: 0.0049 - val_mean_absolute_error: 0.0569
# Epoch 3/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0521 - val_loss: 0.0041 - val_mean_absolute_error: 0.0500
# Epoch 4/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0515 - val_loss: 0.0030 - val_mean_absolute_error: 0.0422
# Epoch 5/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0521 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 6/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0515 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 7/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0523 - val_loss: 0.0020 - val_mean_absolute_error: 0.0345
# Epoch 8/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0512 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 9/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0516 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 10/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0516 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 11/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0518 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 12/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0519 - val_loss: 0.0021 - val_mean_absolute_error: 0.0359
# Epoch 13/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0511 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 1/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0510 - val_loss: 0.0021 - val_mean_absolute_error: 0.0357 - lr: 0.0010
# Epoch 2/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0512 - val_loss: 0.0022 - val_mean_absolute_error: 0.0364 - lr: 0.0010
# Epoch 3/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0511 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352 - lr: 9.0484e-04
# Epoch 4/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0513 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352 - lr: 8.1873e-04
# Epoch 5/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0519 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356 - lr: 7.4082e-04
# Epoch 6/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0513 - val_loss: 0.0021 - val_mean_absolute_error: 0.0357 - lr: 6.7032e-04
# Epoch 7/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0510 - val_loss: 0.0024 - val_mean_absolute_error: 0.0389 - lr: 6.0653e-04
# Epoch 8/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0508 - val_loss: 0.0025 - val_mean_absolute_error: 0.0393 - lr: 5.4881e-04
# Epoch 9/50
# 380/380 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0503 - val_loss: 0.0024 - val_mean_absolute_error: 0.0386 - lr: 4.9659e-04

# %%
plot_history(ms_dnn_history)

# %%
plot_predictions(ms_dnn, ms_sample_batch, 'multi_step')

# %% [markdown]
# ### Evaluation

# %%
ms_mae = [0.1229]
ms_mae.append(ms_dnn.evaluate(test_ds_ms)[1])

x = ['Linear', 'DNN']

fig, ax = plt.subplots()
ax.bar(x, ms_mae, width=0.3)
ax.set_ylabel('MAE')
ax.set_xlabel('Models')
ax.set_ylim(0, max(ms_mae)+0.15)
for index, value in enumerate(ms_mae):
    ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
plt.tight_layout()
# Out:
# 53/53 [==============================] - 0s 2ms/step - loss: 0.0376 - mean_absolute_error: 0.1577

# %% [markdown]
# ## Multi-output model

# %%
train_ds_mo = format_timeseries_data(train_df, 1, 1, ['OT', 'MULL'])
val_ds_mo = format_timeseries_data(val_df, 1, 1, ['OT', 'MULL'])
test_ds_mo = format_timeseries_data(test_df, 1, 1, ['OT', 'MULL'])

mo_sample_batch = next(iter(test_ds_mo))

# %%
mo_dnn = Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(2)
])

mo_dnn_history = train_model(mo_dnn, train_ds_mo, val_ds_mo)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 1s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.0774 - val_loss: 0.0282 - val_mean_absolute_error: 0.1401
# Epoch 2/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0050 - mean_absolute_error: 0.0532 - val_loss: 0.0129 - val_mean_absolute_error: 0.0912
# Epoch 3/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0039 - mean_absolute_error: 0.0474 - val_loss: 0.0170 - val_mean_absolute_error: 0.1033
# Epoch 4/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0035 - mean_absolute_error: 0.0446 - val_loss: 0.0091 - val_mean_absolute_error: 0.0725
# Epoch 5/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0034 - mean_absolute_error: 0.0430 - val_loss: 0.0058 - val_mean_absolute_error: 0.0586
# Epoch 6/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0028 - mean_absolute_error: 0.0391 - val_loss: 0.0071 - val_mean_absolute_error: 0.0662
# Epoch 7/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0356 - val_loss: 0.0094 - val_mean_absolute_error: 0.0760
# Epoch 8/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 0.0082 - val_mean_absolute_error: 0.0702
# Epoch 9/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0329 - val_loss: 0.0067 - val_mean_absolute_error: 0.0658
# Epoch 10/50
# 382/382 [==============================] - 1s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0318 - val_loss: 0.0071 - val_mean_absolute_error: 0.0688

# %%
plot_history(mo_dnn_history)

# %%
plot_predictions(mo_dnn, mo_sample_batch, 'multi_output')

# %% [markdown]
# ### Evaluation

# %%
def plot_evaluation(model_list, mae):
    
    fig, ax = plt.subplots()
    
    ax.bar(model_list, mae, width=0.3)
    ax.set_ylabel('MAE')
    ax.set_xlabel('Models')
    ax.set_ylim(0, max(mae)+0.15)
    for index, value in enumerate(mae):
        ax.text(x=index, y=value+0.005, s=str(round(value, 3)), ha='center')
    
    plt.tight_layout()

# %%
model_list = ['Linear', 'DNN']

mo_mae = [0.0495]
mo_mae.append(mo_dnn.evaluate(test_ds_mo)[1])

plot_evaluation(model_list, mo_mae)
# Out:
# 55/55 [==============================] - 0s 964us/step - loss: 0.0156 - mean_absolute_error: 0.0996
